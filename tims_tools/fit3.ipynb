# %%
file="""
MPI VERSION Intel(R) MPI Library 2019 Update 7 for Linux* OS

got file
0
1
3
0 r104u33 3.341203e-10 1.098961e-07
1 r104u33 3.341205e-10 1.396984e-07
2 r105u33 3.341216e-10 4.563481e-08
3 r105u33 3.341215e-10 8.381903e-08
 S  R       Size     Min Time     Ave Time     Max Time       Bandwidth    #
 0  1          1 7.675961e-07 1.211164e-06 3.744848e-06      2.6055e+06  200
 0  1          4 7.680617e-07 8.148146e-07 1.264736e-06      1.0416e+07  200
 0  1         16 7.708557e-07 8.157594e-07 1.196098e-06      4.1512e+07  200
 0  1         64 8.275732e-07 9.107147e-07 1.373421e-06      1.5467e+08  200
 0  1        256 1.177471e-06 1.351301e-06 1.979154e-06      4.3483e+08  200
 0  1       1024 1.897290e-06 2.007050e-06 3.466010e-06      1.0794e+09  200
 0  1       4096 3.106799e-06 3.503265e-06 4.047807e-06      2.6368e+09  200
 0  1      16384 7.283315e-06 8.008791e-06 9.667408e-06      4.4991e+09  200
 0  1      65536 2.258811e-05 2.398598e-05 2.772212e-05      5.8027e+09  200
 0  1     262144 8.649016e-05 8.761058e-05 1.046621e-04      6.0618e+09  200
 0  1    1048576 4.709262e-04 4.741132e-04 6.125520e-04      4.4532e+09  200
 0  1    4194304 2.022812e-03 2.028504e-03 2.175052e-03      4.1470e+09  200
 0  1   16777216 8.056504e-03 8.062784e-03 8.069235e-03      4.1649e+09   64
 0  1   67108864 3.232496e-02 3.234297e-02 3.236378e-02      4.1521e+09   17
 0  1  268435456 1.292834e-01 1.293061e-01 1.293390e-01      4.1527e+09    5
 0  1 1073741824 5.169598e-01 5.169691e-01 5.169783e-01      4.1541e+09    2
 0  3          1 3.399141e-06 3.514830e-06 9.421911e-06      5.8838e+05  200
 0  3          4 3.425404e-06 3.487658e-06 3.866944e-06      2.3355e+06  200
 0  3         16 3.455579e-06 3.523439e-06 3.989413e-06      9.2604e+06  200
 0  3         64 3.633741e-06 3.774925e-06 4.443340e-06      3.5225e+07  200
 0  3        256 4.795566e-06 7.322173e-06 4.873665e-04      1.0677e+08  200
 0  3       1024 5.414616e-06 5.520933e-06 6.159861e-06      3.7824e+08  200
 0  3       4096 7.937662e-06 8.175718e-06 9.299349e-06      1.0320e+09  200
 0  3      16384 1.395661e-05 1.417485e-05 1.614066e-05      2.3478e+09  200
 0  3      65536 2.513519e-05 2.569223e-05 3.723893e-05      5.2147e+09  200
 0  3     262144 7.362850e-05 7.464297e-05 9.606089e-05      7.1207e+09  200
 0  3    1048576 1.996289e-04 2.020921e-04 2.351729e-04      1.0505e+10  200
 0  3    4194304 7.165979e-04 7.220088e-04 7.886006e-04      1.1706e+10  200
 0  3   16777216 2.789819e-03 2.804708e-03 3.033335e-03      1.2027e+10  180
 0  3   67108864 1.142801e-02 1.149234e-02 1.192012e-02      1.1745e+10   45
 0  3  268435456 4.909579e-02 4.936603e-02 5.070240e-02      1.0935e+10   12
 0  3 1073741824 2.128172e-01 2.150870e-01 2.213079e-01      1.0091e+10    4
 1  3          1 3.228709e-06 3.307378e-06 7.793959e-06      6.1944e+05  200
 1  3          4 3.230758e-06 3.268059e-06 3.660657e-06      2.4762e+06  200
 1  3         16 3.263447e-06 3.325682e-06 3.651250e-06      9.8056e+06  200
 1  3         64 3.386568e-06 3.487824e-06 4.274864e-06      3.7796e+07  200
 1  3        256 4.418474e-06 5.681046e-06 2.403997e-04      1.1588e+08  200
 1  3       1024 5.004648e-06 5.073910e-06 5.433150e-06      4.0922e+08  200
 1  3       4096 7.390138e-06 7.464951e-06 7.893797e-06      1.1085e+09  200
 1  3      16384 1.294417e-05 1.305615e-05 1.424141e-05      2.5315e+09  200
 1  3      65536 2.100077e-05 2.131112e-05 2.707187e-05      6.2413e+09  200
 1  3     262144 5.781194e-05 5.856567e-05 6.985627e-05      9.0689e+09  200
 1  3    1048576 1.994015e-04 2.004744e-04 2.186413e-04      1.0517e+10  200
 1  3    4194304 7.158614e-04 7.190474e-04 7.419328e-04      1.1718e+10  200
 1  3   16777216 2.783623e-03 2.810526e-03 3.369375e-03      1.2054e+10  180
 1  3   67108864 1.128970e-02 1.133277e-02 1.190607e-02      1.1889e+10   46
 1  3  268435456 4.705594e-02 4.716406e-02 4.797960e-02      1.1409e+10   12
 1  3 1073741824 2.138166e-01 2.148175e-01 2.167939e-01      1.0044e+10    4
   0 core   14
   1 core   29
   2 core    1
   3 core   32
Barriers/Second 418237
"""

# %%
input="out.txt"
dat=open("out.txt","r")
file=dat.read()
f=file.split("\n")

# %%
from numpy import polyfit as fit
from numpy import log as log
from numpy import exp as exp
from numpy import poly1d as poly1d

# %%
pairs=[]
dump=True
for l in f:
    if l.find("Barriers/Second") > -1 :
        print(l)
    if l.find("1073741824") > -1 :
        n=l.find("1073741824")
        pair=l[0:n]
        pairs.append(pair)
out=0
outmax=1
for p in pairs[0:2]:
    data=[]
    print("task pairs",p)
    x=[]
    y=[]
    for l in f:
        if l.find(p) > -1 :
            l=l.split()
            d1=float(l[2])
            d2=float(l[6])
            x.append(d1)
            y.append(d2)
    #print(x,y)
    power=1
    bot=0
    top=7
    coef=fit(log(x[bot:top]), log(y[bot:top]), power)
    #print(coef)
    g=poly1d(coef)
    if out <= outmax:
        if out == 0 : path="on_node_"
        if out == 1 : path="off_node_"
        coefstr=str(coef)
        coefstr=coefstr.replace("[","")
        coefstr=coefstr.replace("]","")
        print(path+"low",coefstr)
    for [x1,y1] in zip(x[bot:top],y[bot:top]):
        z=g(log(x1))
        z=exp(z)
        if dump : print("%10.0f %15.0f  %15.0f %7.4f" %(x1,z,y1,y1/z))
    bot=top
    top=len(x)
    coef=fit(log(x[bot:top]), log(y[bot:top]), power)
    if out <= outmax:
        if out == 0 : path="on_node_"
        if out == 1 : path="off_node_"
        coefstr=str(coef)
        coefstr=coefstr.replace("[","")
        coefstr=coefstr.replace("]","")
        print(path+"high",coefstr)
    out=out+1
    g=poly1d(coef)
    for [x1,y1] in zip(x[bot:top],y[bot:top]):
        z=g(log(x1))
        z=exp(z)
        if dump : print("%10.0f %15.0f  %15.0f %7.4f" %(x1,z,y1,y1/z))
